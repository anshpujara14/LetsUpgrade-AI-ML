# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('general_data.csv')
data.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
data.corr()
# Out:
#                               Age  DistanceFromHome  Education  EmployeeCount  \
# Age                      1.000000          0.006963  -0.035706            NaN
# DistanceFromHome         0.006963          1.000000  -0.008638            NaN
# Education               -0.035706         -0.008638   1.000000            NaN
# EmployeeCount                 NaN               NaN        NaN            NaN
# EmployeeID               0.008649         -0.001097  -0.009680            NaN
# JobLevel                -0.002884         -0.037329   0.045746            NaN
# MonthlyIncome           -0.044314         -0.021607   0.006410            NaN
# NumCompaniesWorked       0.299243         -0.013843  -0.016250            NaN
# PercentSalaryHike       -0.033137          0.038125  -0.040531            NaN
# StandardHours                 NaN               NaN        NaN            NaN
# StockOptionLevel        -0.031753          0.011169   0.001261            NaN
# ...

# %%
data.shape
# Out:
# (4410, 24)

# %%
data.isna().any()
# Out:
# Age                        False
# Attrition                  False
# BusinessTravel             False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# EmployeeCount              False
# EmployeeID                 False
# Gender                     False
# JobLevel                   False
# JobRole                    False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked          True
# Over18                     False
# PercentSalaryHike          False
# StandardHours              False
# StockOptionLevel           False
# TotalWorkingYears           True
# TrainingTimesLastYear      False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# YearsWithCurrManager       False
# dtype: bool

# %%
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
data['TotalWorkingYears']
# Out:
# 0        1.0
# 1        6.0
# 2        5.0
# 3       13.0
# 4        9.0
#         ...
# 4405    10.0
# 4406    10.0
# 4407     5.0
# 4408    10.0
# 4409     NaN
# Name: TotalWorkingYears, Length: 4410, dtype: float64

# %%
fill = round(data['TotalWorkingYears'].mean(), 0)
data['TotalWorkingYears'].fillna(fill, inplace=True)
print(data['TotalWorkingYears'].isna().sum())
# Out:
# 0

# %%
data['NumCompaniesWorked']
# Out:
# 0       1.0
# 1       0.0
# 2       1.0
# 3       3.0
# 4       4.0
#        ...
# 4405    3.0
# 4406    2.0
# 4407    0.0
# 4408    0.0
# 4409    0.0
# Name: NumCompaniesWorked, Length: 4410, dtype: float64

# %%
fill = round(data['NumCompaniesWorked'].mean(), 0)
data['NumCompaniesWorked'].fillna(fill, inplace=True)

# %%
data.isna().any()
# Out:
# Age                        False
# Attrition                  False
# BusinessTravel             False
# Department                 False
# DistanceFromHome           False
# Education                  False
# EducationField             False
# EmployeeCount              False
# EmployeeID                 False
# Gender                     False
# JobLevel                   False
# JobRole                    False
# MaritalStatus              False
# MonthlyIncome              False
# NumCompaniesWorked         False
# Over18                     False
# PercentSalaryHike          False
# StandardHours              False
# StockOptionLevel           False
# TotalWorkingYears          False
# TrainingTimesLastYear      False
# YearsAtCompany             False
# YearsSinceLastPromotion    False
# YearsWithCurrManager       False
# dtype: bool

# %% [markdown]
# ### We observe that more than half of the employees have to stay under the same manager for more than 2 years.

# %%
data[data['YearsWithCurrManager'] > 2]
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# 5      46        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4399   34        No      Travel_Rarely  Research & Development
# 4403   39        No  Travel_Frequently  Research & Development
# 4404   29        No      Travel_Rarely                   Sales
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                   10          1  Life Sciences              1           2
# ...

# %%
data['YearsWithCurrManager'].mode()
print("Max years with a manager", data['YearsWithCurrManager'].max())
print('Mean years with a manager', data['YearsWithCurrManager'].mean())
# Out:
# Max years with a manager 17
# Mean years with a manager 4.12312925170068

# %%
print("Average working years of an employee", int(data['TotalWorkingYears'].mean()))
print("Minimum working years of an employee", data['TotalWorkingYears'].min())
print("Max working years of an employee", data['TotalWorkingYears'].max())
# Out:
# Average working years of an employee 11
# Minimum working years of an employee 0.0
# Max working years of an employee 40.0

# %% [markdown]
# ### Also there are more than 200 employees who stays under same Manager for more than 10 years which does not introduce innovation to the team and sometime leads to failure/ slowing down of project due to traditional methods

# %% [markdown]
# Employees working under same manager for more than 10 years

# %%
data[data['YearsWithCurrManager'] > 10]
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 11     36        No      Travel_Rarely  Research & Development
# 12     55        No      Travel_Rarely  Research & Development
# 53     45        No  Travel_Frequently  Research & Development
# 86     35        No      Travel_Rarely                   Sales
# 101    36        No  Travel_Frequently  Research & Development
# ...   ...       ...                ...                     ...
# 4310   40        No      Travel_Rarely  Research & Development
# 4339   55        No      Travel_Rarely  Research & Development
# 4375   38        No      Travel_Rarely  Research & Development
# 4383   42        No      Travel_Rarely  Research & Development
# 4389   52        No         Non-Travel  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 11                  28          1     Life Sciences              1
# 12                  14          4     Life Sciences              1
# ...

# %% [markdown]
# Employees working for less than 10 years in the company and under same manager for more than 7 years

# %%
data[(data['YearsWithCurrManager'] > 7) & (data['TotalWorkingYears'] < 10)]
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 352    27        No      Travel_Rarely                   Sales
# 361    33        No      Travel_Rarely  Research & Development
# 438    45        No         Non-Travel  Research & Development
# 460    45        No         Non-Travel                   Sales
# 631    27        No      Travel_Rarely  Research & Development
# 690    30        No      Travel_Rarely  Research & Development
# 701    40        No      Travel_Rarely                   Sales
# 982    39        No         Non-Travel  Research & Development
# 1070   27        No      Travel_Rarely                   Sales
# 1140   33        No  Travel_Frequently  Research & Development
# 1268   35        No  Travel_Frequently  Research & Development
# 1272   32        No      Travel_Rarely  Research & Development
# 1822   27        No      Travel_Rarely                   Sales
# 1831   33        No      Travel_Rarely  Research & Development
# ...

# %% [markdown]
# #### It is observed that there are employees working under same manager for more than 7 years has left the job in less than 10 years

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
data1 = data.skew()
data1
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# EmployeeCount              0.000000
# EmployeeID                 0.000000
# JobLevel                   1.024703
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.027310
# PercentSalaryHike          0.820569
# StandardHours              0.000000
# StockOptionLevel           0.968321
# TotalWorkingYears          1.118188
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
data2 = data.kurt()
data2
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# EmployeeCount              0.000000
# EmployeeID                -1.200000
# JobLevel                   0.395525
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.017745
# PercentSalaryHike         -0.302638
# StandardHours              0.000000
# StockOptionLevel           0.361086
# TotalWorkingYears          0.921245
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %%
plt.boxplot(data.Age)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x152be28f748>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x152bea9f148>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x152be5d6a48>],
#  'medians': [<matplotlib.lines.Line2D at 0x152beaa2908>],
#  'fliers': [<matplotlib.lines.Line2D at 0x152beaa2d88>],
#  'means': []}

# %%
plt.boxplot(data['MonthlyIncome'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x152bf235708>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x152bf235e48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x152bf231cc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x152bf23bf88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x152bf23fdc8>],
#  'means': []}
